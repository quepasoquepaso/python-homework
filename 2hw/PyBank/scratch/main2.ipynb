# %%
###TESTING FILE



from pathlib import Path
import csv
import numpy_financial as npf

# Set the file path
filepath = Path("Resources/budget_data.csv")

# Initialize list of records
records = []

list_totpnl = []

# Initialize total profit and losses
tot_pnl = 0

# Open the csv file as an object
#with open(filepath, "r") as csvfile:
with open(filepath, 'rb') as csvfile:
    csvreader = csv.reader(csvfile)
    rows = list(csvreader)      # Read all rows into a list

    for row in rows[1:]:         # Skip the header row
        row[1] = int(row[1])

print(rows)
    #tot_pnl = 0
    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    #csvreader = csv.reader(csvfile, delimiter=',')
   
    # Read the header row first (skip this step if there is no header)
csv_header = next(csvreader)

    # Print the header
    #print(csv_header)

    # Append the column 'Average' to the header
    #csv_header.append("Date")
    # Append the header to the list of records
    #records.append(csv_header)


    #for row in csvreader:
	 #   print(row[::2])
    
for row in csvreader:
        # Print the row
        #print(row)

        # Set the 'name', 'count', and 'revenue' variables for better
        # readability, convert strings to ints for numerical calculations
        #name = row[0]
        records.append(row)
        #int(i) for row in csvreader]
        
        #list_totpnl.append([row:1])
        #print(records)
        #row_count = sum(1 for row in csvreader)  # fileObject is your csv.reader
        #count = int(row[1])
        #print(count)
        #print(f'Total Months:{records}')
        #revenue = int(row[2])
#row_count = sum(1 for row in fileObject)  # fileObject is your csv.reader
        # Calculate the average and round to the nearest 2 decimal places
        #average = round(revenue / count, 2)

        # Append the average to the row
        #row.append(average)
        # Append the row to the list of records
        #records.append(row)
#print(records)

#print("Total Months:", len(records)

        #Calculate - The net total amount of Profit/Losses over the entire period.
        #tot_pnl = tot_pnl + records[row]

        #records[2:5:2]
#i = 0
#while i < len(records):
#while i < len(records):
    #i = i + 2
    #tot_pnl=tot_pnl+i
    #print(tot_pnl)




#INSTRUCTIONS - The total number of months included in the dataset.

print(f'Total Months:{len(records)}')

#INSTRUCTIONS - The net total amount of Profit/Losses over the entire period.
#for x in records:
  #print(x)
  #tot_pnl = tot_pnl + [x:1]

records_dict = {x[0]: x[1:] for x in records}





print(values)


print(f'Total Profit/Losses: {(tot_pnl)}')
#print(records[::2])
#INSTRUCTIONS - The average of the changes in Profit/Losses over the entire period.

#INSTRUCTIONS - The greatest increase in profits (date and amount) over the entire period.

#INSTRUCTIONS - The greatest decrease in losses (date and amount) over the entire period.

#INSTRUCTIONS - Your final script should print the analysis to the terminal and export a text file with the results.
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-3-02016e5f046b> in <module>
#      18 with open(filepath, 'rb') as csvfile:
#      19     csvreader = csv.reader(csvfile)
# ---> 20     rows = list(csvreader)      # Read all rows into a list
#      21
#      22     for row in rows[1:]:         # Skip the header row
#
# Error: iterator should return strings, not bytes (did you open the file in text mode?)
